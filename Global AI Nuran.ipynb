# %%
#homework1

value1 = input("1.değeri giriniz: ")
print(f'Girdiğiniz değer: {value1}  ' + "Veri tipi: {}".format(type(value1)))
value2 = input("2.değeri giriniz")
print(f'Girdiğiniz değer: {value2}  ' + "Veri tipi: {}".format(type(value2)))
value3 = input("3.değeri giriniz")
print(f'Girdiğiniz değer: {value3}  ' + "Veri tipi: {}".format(type(value3)))
value4 = input("4.değeri giriniz")
print(f'Girdiğiniz değer: {value4}  ' + "Veri tipi: {}".format(type(value4)))
value5 = input("5.değeri giriniz")
print(f'Girdiğiniz değer: {value5}  ' + "Veri tipi: {}".format(type(value5)))

# %%
#homework2
First = input("Enter your first name: ")
Last = input("Enter your last name: ")
Age= int(input("How old are you? "))
Birth_Year= int(input("Enter your birth year: "))

list=[First,Last,Age,Birth_Year]

for i in range(len(list)):
    print (list[i])
    
if Age<18:
    print("You can't go out because it's too dangerous!")
else:
    print("You can go out to the street")

# %%
#homework3

user=input("Please enter your user name: ")
print(f'Welcome {user}')
    
word="PATATES"
list=[]

for i in range(len(word)):
    list.insert(i," _ ")
    i+=1

t=6    
print(f'Guess: {list}'+ " You have {} right to try.".format(t))

lett=input("Tell me a letter: ").capitalize()

while t>0:
    for i in range(len(word)):
        if lett==word[i]:
            list[i]=lett
            i+=1

        elif lett!=word[i]:
            i+=1
        continue
    print(list) 
    t-=1
    if list.count(" _ ")!=0 and t>0:  
        lett=input("You have {} try left. Tell me another letter: ".format(t)).capitalize()
        continue
    elif list.count(" _ ")==0 or t==0:
        print ("Game is over!")
        break
# Out:
# Please enter your user name: sg
# Welcome sg
# Guess: [' _ ', ' _ ', ' _ ', ' _ ', ' _ ', ' _ ', ' _ '] You have 5 right to try.
# Tell me a letter: a
# [' _ ', 'A', ' _ ', 'A', ' _ ', ' _ ', ' _ ']
# You have 4 try left. Tell me another letter: r
# [' _ ', 'A', ' _ ', 'A', ' _ ', ' _ ', ' _ ']
# You have 3 try left. Tell me another letter: e
# [' _ ', 'A', ' _ ', 'A', ' _ ', 'E', ' _ ']
# You have 2 try left. Tell me another letter:
# [' _ ', 'A', ' _ ', 'A', ' _ ', 'E', ' _ ']
# You have 1 try left. Tell me another letter: w
# [' _ ', 'A', ' _ ', 'A', ' _ ', 'E', ' _ ']
# Game is over!

# %%
#project
student_name = "Aylin"
student_surname = "Aslan"
t=0
while(t<3):
    name = input("Enter your name: ")
    surname = input("Enter your surname: ")
    if student_name==name and student_surname==surname:
        print("Welcome")
        break
    else:
        print("Invalid Name/Surname")
        t+=1
        continue 
while(t>=3):
    print("Try again later")
    break

print("Enter your courses: ")   
courses=[input("1.course: "),input("2.course: "),input("3.course: "),input("4.course: "),input("5.course: ")]
print(courses)
num=int(input("How many course do you take? "))
if num<3 or num>5:
    print("You failed in class!")
withgrades = {}
chosen = input("Choose a course ")
grade=[int(input("midterm: ")),int(input("final: ")), int(input("project: "))]

withgrades['midterm'] = grade[0]
withgrades['final'] = grade[1]
withgrades['project'] = grade[2]
withgrades

total = withgrades['midterm']*0.3 + withgrades['final']*0.5+ withgrades['project']*0.2
total
if total <100:
    if total >= 90:
        print('AA')
    elif total >= 70:
        print('BB')
    elif total >=50:
        print('CC')
    elif total >=30:
        print('DD')
    else:
        print('You fail!!')
else:
    print('Enter valid scores!')
# Out:
# Enter your name: sdf
# Enter your surname: sf
# Invalid Name/Surname
# Enter your name: sfa
# Enter your surname: asf
# Invalid Name/Surname
# Enter your name: asf
# Enter your surname: asf
# Invalid Name/Surname
# Try again later
# Enter your courses:
# 1.course: saf
# 2.course: sf
# 3.course: saf
# 4.course: sf
# 5.course: fs
# ['saf', 'sf', 'saf', 'sf', 'fs']
# How many course do you take? 3
# Choose a course we
# midterm: 123
# final: 32
# project: 32
# CC
